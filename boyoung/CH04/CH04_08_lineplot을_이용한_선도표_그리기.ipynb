# %% [markdown]
# linechart를 이용한 선도표 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc = {'figure.figsize':(10,5)})
import pandas as pd

# %%
df = sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# - 결측값 확인

# %%
df.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %% [markdown]
# - 선표도 그리기

# %%
sns.lineplot(data = df, x = 'year', y = 'passengers') # 연도별 승객수 그리기

# %% [markdown]
# - xtick에 전체년도 표시

# %%
sns.lineplot(data = df, x = 'year', y= 'passengers')
plt.xticks(df['year']);

# %% [markdown]
# - xtick 기울기 추가

# %%
sns.lineplot(data = df, x = 'year', y = 'passengers')
plt.xticks(df['year'], rotation = 45);

# %%
sns.lineplot(data = df,x = 'year', y = 'passengers', hue = 'month')

# %%
sns.lineplot(data = df,x = 'year', y = 'passengers', hue = 'month', palette = 'Set2')

# %%
sns.lineplot(data = df,x = 'year', y = 'passengers', hue = 'month', palette = 'Set2', style = 'month')
