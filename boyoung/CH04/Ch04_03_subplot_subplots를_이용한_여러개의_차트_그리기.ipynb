# %% [markdown]
# # subplot / subplots 를 이용한 여러개의 차트 그리기

# %%
import matplotlib.pyplot as plt

# %%
x1 = [1, 2, 3]
y1 = [1, 2, 3]
x2 = [1, 2, 3]
y2 = [1, 100, 200]

# %% [markdown]
# - subplot을 이용한 해결
#
# subplot(행의수, 열의수, 해당 그래프가 그려질 위치)

# %%
plt.subplot(1,2,1)
plt.plot(x1, y1)
plt.title('data1')

plt.subplot(1,2,2)
plt.plot(x2, y2)
plt.title('data2')
# Out:
# Text(0.5, 1.0, 'data2')

# %%
plt.subplot(2,1,1)
plt.plot(x1, y1)
plt.title('data1')

plt.subplot(2,1,2)
plt.plot(x2, y2)
plt.title('data2')
# Out:
# Text(0.5, 1.0, 'data2')

# %% [markdown]
# - tight_layout 을 이용하면 레이아웃이 자동 설정

# %%
plt.subplot(2,1,1)
plt.plot(x1, y1)
plt.title('data1')

plt.subplot(2,1,2)
plt.plot(x1,y1)
plt.title('data2')

plt.tight_layout()

# %% [markdown]
# subplots를 이용한 해결

# %%
fig, axe1 = plt.subplots(nrows = 1, ncols =2)

# %%
fig # fig에는 도화지가 저장됨

# %%
axe1
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a240d4410>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a245372d0>],
#       dtype=object)

# %%
axe1[0].plot(x1, y1, color = 'blue')

# %%
fig

# %%
axe1[1].plot(x2, y2, color = 'red')

# %%
fig

# %% [markdown]
# - 문제: data1(x :1,2,3, y:1,2,3)과 data2(x:1,2,3, y:1,50,200)을 그래프로 출력하시오.

# %%
x1 = [1,2,3]
y1 = [1,2,3]
x2 = [1,2,3]
y2 = [1, 50, 200]

# %%
fig, axe1 = plt.subplots()

axe2 = axe1.twinx()
axe1.plot(x1, y1, color = 'red', label = 'data1')
axe2.plot(x2, y2, color = 'blue', label = 'data2')

axe1.set_xlabel('x', fontsize = 15)
axe1.set_ylabel('y', fontsize = 15)
axe2.set_ylabel('y2', fontsize = 15)
# Out:
# Text(0, 0.5, 'y2')

# %% [markdown]
# - 축을 두개 가진 차트에서 범례 표시하기

# %%
fig, axe1 = plt.subplots()

axe2 = axe1.twinx()
chart1 = axe1.plot(x1, y1, color = 'red')
chart2 = axe2.plot(x2, y2, color = 'blue')

axe1.set_xlabel('x', fontsize = 15)
axe1.set_ylabel('y', fontsize = 15)
axe2.set_ylabel('y2', fontsize = 15)

chart =  chart1 + chart2
axe1.legend(chart, ['data1', 'data2'])
